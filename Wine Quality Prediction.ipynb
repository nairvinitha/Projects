# %% [markdown]
# Predicting the quality of wine: Target variable -> Quality

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\vinit\Downloads\QualityPrediction.csv")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# ...

# %%
df.shape
#Another way for displaying the shape of the dataframe is by typing the following commands:
#print('No. of rows',df.shape[0])
#print('No.of columns',df.shape[1])
# Out:
# (1599, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
#check for any null values
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#Find the descriptive statistics of the dataframe variables
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %% [markdown]
# Performing Bivariate analysis (checking the relationship between two variables out of which one of them is the target variable,
# 'quality':

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
df.hist(bins=25,figsize=(10,10))
# display histogram
plt.show()

# %%
#plot the bar plots to visualize the bivariate relationship. Easier to understand
import matplotlib.pyplot as plt

plt.bar(df['quality'], df['fixed acidity'])
plt.xlabel('Wine Quality')
plt.ylabel('Fixed Acidity')
plt.show()

#From the below plot we see that as the fixed acidity increases the quality of wine also increases

# %%
#display bar plots to check the relationship of the rest of the features with 'quality'
plt.bar(df['quality'], df['volatile acidity'])
plt.xlabel('Wine Quality')
plt.ylabel('Volatile Acidity')
plt.show()

#From the below plot we see that as the volatile acidity increases, the quality of wine decreases (inversely proportional)

# %%
plt.bar(df['quality'], df['citric acid'])
plt.xlabel('Wine Quality')
plt.ylabel('Citric Acid')
plt.show()

#the below plot shows that citric acid does not have much influence on the quality of wine. Except when the acidity is approx.
#1, the quality of wine is at 4 (still poor quality)

# %%
plt.bar(df['quality'], df['residual sugar'])
plt.xlabel('Wine Quality')
plt.ylabel('Residual Sugar')
plt.show()

#lesser the amount of residual sugar, better the quality of wine

# %%
plt.bar(df['quality'], df['chlorides'])
plt.xlabel('Wine Quality')
plt.ylabel('Chlorides')
plt.show()

#lesser the presence of chlorides, better the quality of wine

# %%
plt.bar(df['quality'], df['total sulfur dioxide'])
plt.xlabel('Wine Quality')
plt.ylabel('Sulphur Dioxide')
plt.show()

#Quality of wine is at its best (7) only for a particular amount of Sulphur dioxide. 
#Else it does not have much imapct on the quality.

# %%
plt.bar(df['quality'], df['alcohol'])
plt.xlabel('Wine Quality')
plt.ylabel('Alcohol Content')
plt.show()

#Higher the alcohol content, better the wine quality

# %% [markdown]
# Displaying a heatmap to show the correlation:

# %%
import seaborn as sns
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(), annot = True, fmt = '0.1f')
plt.show()

# %% [markdown]
# Since we saw Sulphur dioxide and citric acid do not contribute much to the wine quality we can drop those columns:

# %%
df.drop(['total sulfur dioxide', 'citric acid', 'free sulfur dioxide'], axis = 1, inplace = True)
df
# Out:
#       fixed acidity  volatile acidity  residual sugar  chlorides  density  \
# 0               7.4             0.700             1.9      0.076  0.99780
# 1               7.8             0.880             2.6      0.098  0.99680
# 2               7.8             0.760             2.3      0.092  0.99700
# 3              11.2             0.280             1.9      0.075  0.99800
# 4               7.4             0.700             1.9      0.076  0.99780
# ...             ...               ...             ...        ...      ...
# 1594            6.2             0.600             2.0      0.090  0.99490
# 1595            5.9             0.550             2.2      0.062  0.99512
# 1596            6.3             0.510             2.3      0.076  0.99574
# 1597            5.9             0.645             2.0      0.075  0.99547
# 1598            6.0             0.310             3.6      0.067  0.99549
#
#         pH  sulphates  alcohol  quality
# ...

# %%
df['quality'].value_counts() #checking the count of each quality value in the dataframe
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
#Get all the unique values
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
#To decide if the wine quality is good or not, we should put it in two categories. 'Good wine' and 'Bad wine'. Let these classes
#be assigned as 0 and 1. Therefore we should binarize our target variable.

#for x in df['quality']:
 #   if x >= 7:
  #      df['quality'] = 1
   # else:
    #    df['quality'] = 0
        
    #return df['quality']
    
df['quality'] = [1 if x >= 7 else 0 for x in df.quality]
print(df['quality'].unique())
# Out:
# [0 1]

# %%
df['quality'].value_counts()
# Out:
# 0    1382
# 1     217
# Name: quality, dtype: int64

# %% [markdown]
# Splitting the data into training and testing sets:

# %%
#Get all the feature variables into a separate feature matrix, vector x and the target/response variable into separate matrix 
#vector y

x = df.drop(['quality'], axis = 1)
y = df['quality']
print(x)
print(y)
# Out:
#       fixed acidity  volatile acidity  residual sugar  chlorides  density  \
# 0               7.4             0.700             1.9      0.076  0.99780
# 1               7.8             0.880             2.6      0.098  0.99680
# 2               7.8             0.760             2.3      0.092  0.99700
# 3              11.2             0.280             1.9      0.075  0.99800
# 4               7.4             0.700             1.9      0.076  0.99780
# ...             ...               ...             ...        ...      ...
# 1594            6.2             0.600             2.0      0.090  0.99490
# 1595            5.9             0.550             2.2      0.062  0.99512
# 1596            6.3             0.510             2.3      0.076  0.99574
# 1597            5.9             0.645             2.0      0.075  0.99547
# 1598            6.0             0.310             3.6      0.067  0.99549
#
#         pH  sulphates  alcohol
# 0     3.51       0.56      9.4
# ...

# %%
from sklearn.model_selection import train_test_split
train_x, test_x, train_y, test_y = train_test_split(x,y,test_size = 0.2, random_state = 40)

# %%
#to avoid model bias, we need to apply feature scaling so that features with high values do not dominate the distance 
#values between data points
from sklearn.preprocessing import StandardScaler
StdScale = StandardScaler()
train_x = StdScale.fit_transform(train_x)
test_x = StdScale.fit_transform(test_x)
train_x
# Out:
# array([[ 0.4241707 , -0.55139853, -0.01222591, ...,  0.44642772,
#         -0.23034472, -0.88182786],
#        [ 0.77838488, -0.83108438, -0.01222591, ..., -0.79494028,
#          0.23862184, -0.40810469],
#        [-0.99268605,  1.09874799,  2.18843703, ...,  0.25042225,
#         -0.99241539,  0.3498524 ],
#        ...,
#        [-0.75654326,  0.39953336,  1.45488272, ..., -0.07625354,
#          2.99380038, -0.21861541],
#        [ 1.19163477, -0.49546136,  1.45488272, ..., -0.20692386,
#          1.0006925 ,  1.01306485],
#        [ 1.13259907, -0.66327287, -0.2322922 , ..., -0.99094576,
#          0.06275938,  0.3498524 ]])

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn. tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import mean_squared_error
import numpy as np
#creating RandomForestClassifier constructor
RFC = RandomForestClassifier()
# fit data
RFC.fit(train_x, train_y)
# predicting score
RFC_score = RFC.score(test_x,test_y)
print('Model performance score : ',RFC_score)
#predicting on the test set
y_pred1 = RFC.predict(test_x)
#get the classification report
print(classification_report(test_y, y_pred1))
# Out:
# Model performance score :  0.90625
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95       272
#            1       0.85      0.46      0.59        48
#
#     accuracy                           0.91       320
#    macro avg       0.88      0.72      0.77       320
# weighted avg       0.90      0.91      0.89       320

# %%
#checking for Support Vector Machine
SVM = SVC(kernel='rbf')
# fit data
SVM.fit(train_x, train_y)
# predicting score
SVM_score = SVM.score(test_x,test_y)
print('Model performance score : ',SVM_score)
#predicting on the test set
y_pred2 = SVM.predict(test_x)
#get the classification report
print(classification_report(test_y, y_pred2))
# Out:
# Model performance score :  0.85
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92       272
#            1       0.00      0.00      0.00        48
#
#     accuracy                           0.85       320
#    macro avg       0.42      0.50      0.46       320
# weighted avg       0.72      0.85      0.78       320
# C:\Users\vinit\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\vinit\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
#checking for logistic regression model
LR = LogisticRegression()
# fit data
LR.fit(train_x, train_y)
# predicting score
LR_score = LR.score(test_x,test_y)
print('Model performance score : ',LR_score)
#predicting on the test set
y_pred3 = LR.predict(test_x)
#get the classification report
print(classification_report(test_y, y_pred3))
# Out:
# Model performance score :  0.871875
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93       272
#            1       0.71      0.25      0.37        48
#
#     accuracy                           0.87       320
#    macro avg       0.79      0.62      0.65       320
# weighted avg       0.85      0.87      0.84       320
# C:\Users\vinit\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#checking for Decision Tree Classifier 
DTC =  DecisionTreeClassifier()
# fit data
DTC.fit(train_x, train_y)
# predicting score
DTC_score = DTC.score(test_x,test_y)
print('Model performance score : ',DTC_score)
#predicting on the test set
y_pred4 = DTC.predict(test_x)
#get the classification report
print(classification_report(test_y, y_pred4))
# Out:
# Model performance score :  0.9
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.94       272
#            1       0.70      0.58      0.64        48
#
#     accuracy                           0.90       320
#    macro avg       0.81      0.77      0.79       320
# weighted avg       0.89      0.90      0.90       320

# %%
from sklearn.metrics import confusion_matrix
metrics.plot_confusion_matrix(classifiers[0], test_x, test_y)
plt.show()
# Out:
# C:\Users\vinit\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
metrics.plot_confusion_matrix(classifiers[1], test_x, test_y)
plt.show()
# Out:
# C:\Users\vinit\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
